# %% [markdown]
# ## CODE BLOCK 1
#
# ### Description
# pip installs the library for OpenAI.

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (0.27.7)
# Requirement already satisfied: requests>=2.20 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from openai) (3.8.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests>=2.20->openai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests>=2.20->openai) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/blakemeisenheimer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp->openai) (1.3.1)

# %% [markdown]
# ## CODE BLOCK 2
#
# ### Description
# Sets up the importation of Python code libraries and sets up environment variables:
# - OpenAPI key setup
# - Code repository location

# %%
# Import libraries
import os
from glob import glob
import pandas as pd
import openai

# Set OpenAI API key
with open('openai-key.txt', 'r') as f:
    key = f.read().strip()

os.environ['OPENAI_API_KEY'] = key

# Set location of code repo
repoFolder = "/Users/blakemeisenheimer/Documents/breakfree/bench2023/AI_ML/fine-tuning/dragon-bank"
#repoFolder = "openai-cookbook"

# Set code file extension type
extType = "py"

# Set the OpenAI key path
openai.api_key_path = 'openai-key.txt'

# %% [markdown]
# ## CODE BLOCK 3
#
# ### Description
# Defines the functions for creating the dataframe for Python repositories broken down by individual functions

# %%
# Functions to create dataframe for Python repos broken down by individual functions

def get_function_name(code):
    """
    Extract function name from a line beginning with "def "
    """
    assert code.startswith("def ")
    return code[len("def "): code.index("(")]

def get_until_no_space(all_lines, i) -> str:
    """
    Get all lines until a line outside the function definition is found.
    """
    ret = [all_lines[i]]
    for j in range(i + 1, i + 10000):
        if j < len(all_lines):
            if len(all_lines[j]) == 0 or all_lines[j][0] in [" ", "\t", ")"]:
                ret.append(all_lines[j])
            else:
                break
    return "\n".join(ret)

def get_functions(filepath):
    """
    Get all functions in a Python file.
    """
    whole_code = open(filepath).read().replace("\r", "\n")
    all_lines = whole_code.split("\n")
    for i, l in enumerate(all_lines):
        if l.startswith("def "):
            code = get_until_no_space(all_lines, i)
            function_name = get_function_name(code)
            # yield {"function_name": function_name, "code": code, "filepath": filepath}
            yield {"function_name": function_name, "code": code, "filepath": filepath}

# %% [markdown]
# ## CODE BLOCK 4
#
# ### Description
# Creates the pandas dataframe to perform code embedding

# %%
# Create dataframe for code embedding

code_root = repoFolder

code_files = [y for x in os.walk(code_root) for y in glob(os.path.join(x[0], f"*.{extType}"))]
print(f"Total number of {extType} files:", len(code_files))

if extType == "py":
    all_funcs = []
    for code_file in code_files:
        funcs = list(get_functions(code_file))
        for func in funcs:
            all_funcs.append(func)

    print("Total number of functions extracted:", len(all_funcs))

else:
    all_funcs = []
    for code_file in code_files:
        whole_code = open(code_file).read().replace("\r", "\n")
        all_funcs.append({"code": whole_code, "filepath": code_file})


df = pd.DataFrame(all_funcs)
df

# test = pd.DataFrame(all_funcs)
# df = test.head()

# df
# Out:
# Total number of py files: 1
# Total number of functions extracted: 23
#                                         function_name
# 0                                            get_data  \
# 1                                            set_data
# 2                                   get_users_as_list
# 3                                 list_to_linked_list
# 4                                           heap_sort
# 5                                                swap
# 6                                           sift_down
# 7                                  text_binary_search
# 8                                make_text_searchable
# 9                             generate_account_number
# 10                                perform_transaction
# 11                                 update_information
# 12                                    create_new_user
# 13                                     search_account
# 14                                     delete_account
# 15                              clean_terminal_screen
# 16                              print_horizontal_line
# 17  display_account_information_by_given_account_n...
# 18                                display_user_object
# 19                     display_all_accounts_sorted_by
# 20                                 beatify_field_name
# 21         ask_user_what_field_to_sort_the_display_by
# 22                                       display_menu
#
#                                                  code
# 0   def get_data():\n    """\n    Reads the bank i...  \
# 1   def set_data(data):\n    """\n    Writes the b...
# 2   def get_users_as_list():\n    """\n    This fu...
# 3   def list_to_linked_list(arr):\n    """\n    Co...
# 4   def heap_sort(input_list, field):\n    """\n  ...
# 5   def swap(input_list, a, b):\n    """\n    Swap...
# 6   def sift_down(input_list, field, start_index, ...
# 7   def text_binary_search(input_list, field, quer...
# 8   def make_text_searchable(text):\n    """\n    ...
# 9   def generate_account_number():\n    """\n    G...
# 10  def perform_transaction(sender_number, receive...
# 11  def update_information(account_number):\n    "...
# 12  def create_new_user(full_name, balance, gender...
# 13  def search_account(field, query):\n    """\n  ...
# 14  def delete_account(account_number):\n    """\n...
# 15  def clean_terminal_screen():\n    """\n    Cle...
# 16  def print_horizontal_line():\n    """\n    A p...
# 17  def display_account_information_by_given_accou...
# 18  def display_user_object(user_object, account_n...
# 19  def display_all_accounts_sorted_by(field):\n  ...
# 20  def beatify_field_name(field):\n    if field =...
# 21  def ask_user_what_field_to_sort_the_display_by...
# 22  def display_menu():\n    """\n    Displays the...
#
#                                              filepath
# 0   /Users/blakemeisenheimer/Documents/breakfree/b...
# 1   /Users/blakemeisenheimer/Documents/breakfree/b...
# 2   /Users/blakemeisenheimer/Documents/breakfree/b...
# 3   /Users/blakemeisenheimer/Documents/breakfree/b...
# 4   /Users/blakemeisenheimer/Documents/breakfree/b...
# 5   /Users/blakemeisenheimer/Documents/breakfree/b...
# 6   /Users/blakemeisenheimer/Documents/breakfree/b...
# 7   /Users/blakemeisenheimer/Documents/breakfree/b...
# 8   /Users/blakemeisenheimer/Documents/breakfree/b...
# 9   /Users/blakemeisenheimer/Documents/breakfree/b...
# 10  /Users/blakemeisenheimer/Documents/breakfree/b...
# 11  /Users/blakemeisenheimer/Documents/breakfree/b...
# 12  /Users/blakemeisenheimer/Documents/breakfree/b...
# 13  /Users/blakemeisenheimer/Documents/breakfree/b...
# 14  /Users/blakemeisenheimer/Documents/breakfree/b...
# 15  /Users/blakemeisenheimer/Documents/breakfree/b...
# 16  /Users/blakemeisenheimer/Documents/breakfree/b...
# 17  /Users/blakemeisenheimer/Documents/breakfree/b...
# 18  /Users/blakemeisenheimer/Documents/breakfree/b...
# 19  /Users/blakemeisenheimer/Documents/breakfree/b...
# 20  /Users/blakemeisenheimer/Documents/breakfree/b...
# 21  /Users/blakemeisenheimer/Documents/breakfree/b...
# 22  /Users/blakemeisenheimer/Documents/breakfree/b...

# %% [markdown]
# ## CODE BLOCK 5
#
# ### Description
# Create CSV file representing the correlation between each function of code and what the model (currently text-embedding-ada-002) believes it knows about the code.  It calculates the embeddings for code snippets in the 'code' column of the DataFrame using the 'text-embedding-ada-002' engine. It then saves the DataFrame to a CSV file and displays the initial rows of the DataFrame.

# %%
from openai.embeddings_utils import get_embedding
import warnings
warnings.filterwarnings("ignore")

import json

# df['code_embedding'] = df['code'].apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
if extType == "py":
    df['filepath'] = df['filepath'].apply(lambda x: x.replace(code_root, ""))
# df.to_csv("code_search_openai-python.csv", index=False)

df.to_dict
df.head()


####
## Testing dictionary values cleanup after converting dictionary to json
####
# for i in df:
#     print(i)
#     print(df[i])

# def dumper(df):
#     try:
#         return df.toJSON()
#     except:
#         return df.__dict__
# df = df.to_json()

# res = json.dumps(df)
# print(res)
# with open('result.json', 'w') as fp:
#     json.dump(df, fp)
# Out:
#          function_name                                               code
# 0             get_data  def get_data():\n    """\n    Reads the bank i...  \
# 1             set_data  def set_data(data):\n    """\n    Writes the b...
# 2    get_users_as_list  def get_users_as_list():\n    """\n    This fu...
# 3  list_to_linked_list  def list_to_linked_list(arr):\n    """\n    Co...
# 4            heap_sort  def heap_sort(input_list, field):\n    """\n  ...
#
#    filepath
# 0  /bank.py
# 1  /bank.py
# 2  /bank.py
# 3  /bank.py
# 4  /bank.py

# %% [markdown]
# ## Code Block 6
# ### Description
# Iterate over csv file, and have GPT API describe each

# %%
from time import time,sleep

def gpt3_completion(prompt, engine='gpt-3.5-turbo', temp=1.0, top_p=1.0, tokens=1000, freq_pen=0.25, pres_pen=0.25, stop=['<<END>>']):
    max_retry = 5
    retry = 0
    while True:
        try:
            response = openai.ChatCompletion.create(
                model=engine,        
                messages=prompt,        
                temperature=temp)
            # response = openai.ChatCompletion.create(
            #     engine=engine,
            #     prompt=prompt,
            #     temperature=temp,
            #     max_tokens=tokens,
            #     top_p=top_p,
            #     frequency_penalty=freq_pen,
            #     presence_penalty=pres_pen,
            #     stop=stop)
            text = response["choices"][0]["message"]["content"]
            return text
        except Exception as oops:
            retry += 1
            if retry >= max_retry:
                return "GPT3 error: %s" % oops
            print('Error communicating with OpenAI:', oops)
            sleep(1)

# %%
count =0
df['summary']=None
for index, row in df.iterrows():
    function_name = row['function_name']
    code = row['code']
    prompt = f'''Summarize in english what the python function {function_name}
        does and list the required input parameters, output parameters 
        and any external functions called through the following code.
        {code}'''
    messages = [
        {"role": "user", "content": prompt}]
    response = gpt3_completion(messages)
    df.at[index, 'summary'] = response

# %%
# df["summary"].to_csv("summary.csv", index=False)
# df

# for index, row in df.iterrows():
#     function_name = row['function_name']
#     code = row['code']
#     summary = row['summary']
#     prompt = f'''{"prompt": "Function_name: {function_name}\n\n Description: {summary}\n\n completion: {code} }'''

# {"prompt": "Function_name: {function_name}\n\n Description: {summary}\n\n completion: {code} }

import json

listOfDicts = []
for index, row in df.iterrows():
    function_name = row['function_name']
    code = row['code']
    summary = row['summary']
    newDict = {}
    newDict['prompt'] = f"Function_name: {function_name}\n\n Description: {summary}\n\n"
    newDict['completion'] = code
    listOfDicts.append(newDict)
jsonObj = json.dumps(listOfDicts)

with open("DragonBank.json", "w") as f:
    for i in listOfDicts:
        json.dump(i, f)
        f.write('\n')
