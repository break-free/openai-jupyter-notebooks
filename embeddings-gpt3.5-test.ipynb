# %%
# Import libraries
import os
from glob import glob
import pandas as pd
import openai
from openai.embeddings_utils import get_embedding

# Set OpenAI API key
with open('openai-key.txt', 'r') as f:
    key = f.read().strip()

os.environ['OPENAI_API_KEY'] = key

# Set location of code repo
repoFolder = "BF_Planning_Poker/modules"
#repoFolder = "openai-cookbook"

# Set code file extension type
extType = "js"

# %%
openai.api_key_path = 'openai-key.txt'

# %%
# Functions to create dataframe for Python repos broken down by individual functions

def get_function_name(code):
    """
    Extract function name from a line beginning with "def "
    """
    assert code.startswith("def ")
    return code[len("def "): code.index("(")]

def get_until_no_space(all_lines, i) -> str:
    """
    Get all lines until a line outside the function definition is found.
    """
    ret = [all_lines[i]]
    for j in range(i + 1, i + 10000):
        if j < len(all_lines):
            if len(all_lines[j]) == 0 or all_lines[j][0] in [" ", "\t", ")"]:
                ret.append(all_lines[j])
            else:
                break
    return "\n".join(ret)

def get_functions(filepath):
    """
    Get all functions in a Python file.
    """
    whole_code = open(filepath).read().replace("\r", "\n")
    all_lines = whole_code.split("\n")
    for i, l in enumerate(all_lines):
        if l.startswith("def "):
            code = get_until_no_space(all_lines, i)
            function_name = get_function_name(code)
            yield {"code": code, "function_name": function_name, "filepath": filepath}

# %%
# Create dataframe for code embedding

code_root = repoFolder

code_files = [y for x in os.walk(code_root) for y in glob(os.path.join(x[0], f"*.{extType}"))]
print(f"Total number of {extType} files:", len(code_files))

if extType == "py":
    all_funcs = []
    for code_file in code_files:
        funcs = list(get_functions(code_file))
        for func in funcs:
            all_funcs.append(func)

    print("Total number of functions extracted:", len(all_funcs))

else:
    all_funcs = []
    for code_file in code_files:
        whole_code = open(code_file).read().replace("\r", "\n")
        all_funcs.append({"code": whole_code, "filepath": code_file})

df = pd.DataFrame(all_funcs)
df

# test = pd.DataFrame(all_funcs)
# df = test.head()

# df
# Out:
# Total number of js files: 12
#                                                  code  \
# 0   (function(window, angular, undefined) {\n  "us...
# 1   (function(window, angular, undefined) {\n  "us...
# 2   (function(window, angular, undefined) {\n  "us...
# 3   (function(window, angular, undefined) {\n  "us...
# 4   (function(window, angular, undefined) {\n  "us...
# 5   (function(window, angular, undefined) {\n  "us...
# 6   (function(window, angular, undefined) {\n  "us...
# 7   (function(window, angular, undefined) {\n  "us...
# 8   (function(window, angular, undefined) {\n    "...
# 9   (function(window, angular, undefined) {\n    "...
# 10  (function(window, angular, undefined) {\n  "us...
# 11  (function(window, angular, undefined) {\n  "us...
#
#                                              filepath
# 0                    BF_Planning_Poker/modules/App.js
# 1        BF_Planning_Poker/modules/landing/Landing.js
# 2   BF_Planning_Poker/modules/landing/LandingContr...
# 3    BF_Planning_Poker/modules/room/ResultsService.js
# 4       BF_Planning_Poker/modules/room/DeckFactory.js
# 5    BF_Planning_Poker/modules/room/DeckController.js
# 6              BF_Planning_Poker/modules/room/Room.js
# 7    BF_Planning_Poker/modules/room/RoomController.js
# 8   BF_Planning_Poker/modules/siteRequest/SiteRequ...
# 9   BF_Planning_Poker/modules/siteRequest/SiteRequ...
# 10  BF_Planning_Poker/modules/sharedServices/Fireb...
# 11  BF_Planning_Poker/modules/sharedServices/Share...

# %%
from openai.embeddings_utils import get_embedding
import warnings
warnings.filterwarnings("ignore")

df['code_embedding'] = df['code'].apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
if extType == "py":
    df['filepath'] = df['filepath'].apply(lambda x: x.replace(code_root, ""))
df.to_csv("code_search_openai-python.csv", index=False)
df.head()
# Out:
#                                                 code  \
# 0  (function(window, angular, undefined) {\n  "us...
# 1  (function(window, angular, undefined) {\n  "us...
# 2  (function(window, angular, undefined) {\n  "us...
# 3  (function(window, angular, undefined) {\n  "us...
# 4  (function(window, angular, undefined) {\n  "us...
#
#                                             filepath  \
# 0                   BF_Planning_Poker/modules/App.js
# 1       BF_Planning_Poker/modules/landing/Landing.js
# 2  BF_Planning_Poker/modules/landing/LandingContr...
# 3   BF_Planning_Poker/modules/room/ResultsService.js
# 4      BF_Planning_Poker/modules/room/DeckFactory.js
#
#                                       code_embedding
# 0  [-0.003846886334940791, 0.017710193991661072, ...
# 1  [-0.005139595828950405, 0.018938548862934113, ...
# 2  [-0.01231421623378992, 0.012499891221523285, -...
# 3  [-0.010933968238532543, 0.025452183559536934, ...
# 4  [-0.00672426400706172, 0.004281288478523493, -...

# %%
# df = pd.read_csv("code_search_openai-python.csv")
# df.head()

# %%
from openai.embeddings_utils import cosine_similarity

def search_functions(df, code_query, n=3, pprint=False, n_lines=7):
    embedding = get_embedding(code_query, engine='text-embedding-ada-002')
    df['similarities'] = df.code_embedding.apply(lambda x: cosine_similarity(x, embedding))

    res = df.sort_values('similarities', ascending=False).head(n)
    if pprint:
        for r in res.iterrows():
            print(r[1].filepath+":"+r[1].function_name + "  score=" + str(round(r[1].similarities, 3)))
            print("\n".join(r[1].code.split("\n")[:n_lines]))
            print('-'*70)
    return res

res = search_functions(df, 'Write unit tests for the RoomController function', n=3)

# %%
res.head()
# Out:
#                                                 code  \
# 7  (function(window, angular, undefined) {\n  "us...
# 2  (function(window, angular, undefined) {\n  "us...
# 5  (function(window, angular, undefined) {\n  "us...
#
#                                             filepath  \
# 7   BF_Planning_Poker/modules/room/RoomController.js
# 2  BF_Planning_Poker/modules/landing/LandingContr...
# 5   BF_Planning_Poker/modules/room/DeckController.js
#
#                                       code_embedding  similarities
# 7  [-0.006216228473931551, 0.01109306700527668, -...      0.809942
# 2  [-0.01231421623378992, 0.012499891221523285, -...      0.787318
# 5  [-0.012685777619481087, 0.0073215835727751255,...      0.779079

# %%
color_prefix_by_role = {
    "system": "\033[0m",  # gray
    "user": "\033[0m",  # gray
    "assistant": "\033[92m",  # green
}


def print_messages(messages, color_prefix_by_role=color_prefix_by_role) -> None:
    """Prints messages sent to or from GPT."""
    for message in messages:
        role = message["role"]
        color_prefix = color_prefix_by_role[role]
        content = message["content"]
        print(f"{color_prefix}\n[{role}]\n{content}")


def print_message_delta(delta, color_prefix_by_role=color_prefix_by_role) -> None:
    """Prints a chunk of messages streamed back from GPT."""
    if "role" in delta:
        role = delta["role"]
        color_prefix = color_prefix_by_role[role]
        print(f"{color_prefix}\n[{role}]\n", end="")
    elif "content" in delta:
        content = delta["content"]
        print(content, end="")
    else:
        pass

# %%
def ask(
    query: str,
    df: pd.DataFrame = df,
    model: str = "gpt-3.5-turbo",
    print_message: bool = True,
) -> str:
    """Answers a query using GPT and a dataframe of relevant texts and embeddings."""
    res = search_functions(df, query, n=3)

    # Loop through each row of the dataframe
    context = ""
    for index, row in res.iterrows():
        # Access the value in the 'column_name' column for the current row
        filePath = row['filepath']
        code = row['code']
        combined = f'''\n\nCode File Location: {filePath}\nCode: {code}'''
        context = context + combined
    
    message = f'''
    Use the below code to respond to this prompt: {query}
    {context}
    '''

    messages = [
        {"role": "system", "content": "You are a world-class developer with an eagle eye for unintended bugs and edge cases. You carefully explain code with great detail and accuracy. You organize your explanations in markdown-formatted, bulleted lists."},
        {"role": "user", "content": message},
    ]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.5,
        stream=True
    )
    
    execution = ""
    for chunk in response:
        delta = chunk["choices"][0]["delta"]
        if print_message:
            print_message_delta(delta)
        if "content" in delta:
            execution += delta["content"]
    
    #response_message = response["choices"][0]["message"]["content"]
    response_message = ""
    return response_message

# %%
response = ask('Write unit tests for the RoomController function.')
# Out:
# [assistant]
# Unit Tests for RoomController function:
#
# 1. Test if $scope.changeDeck function updates $scope.room and $cookieStore:
# ```
# describe('RoomController', function() {
#   beforeEach(module('ATS.Room'));
#
#   var $controller, $rootScope, $scope, $cookieStore, $q, FirebaseService;
#   var mockRoom = {
#     $save: function() {
#       var deferred = $q.defer();
#       deferred.resolve();
#       return deferred.promise;
#     }
#   };
#
#   beforeEach(inject(function(_$controller_, _$rootScope_, _$cookieStore_, _$q_, _FirebaseService_) {
#     $controller = _$controller_;
#     $rootScope = _$rootScope_;
#     $scope = $rootScope.$new();
#     $cookieStore = _$cookieStore_;
#     $q = _$q_;
#     FirebaseService = _FirebaseService_;
#
#     spyOn($cookieStore, 'put');
#     spyOn(mockRoom, '$save').and.callThrough();
#
#     $controller('RoomController', {
#       $rootScope: $rootScope,
#       $scope: $scope,
#       $routeParams: {},
#       $location: {},
#       $cookieStore: $cookieStore,
#       FirebaseService: FirebaseService,
#       ResultsService: {},
#       DeckFactory: {},
#       $mdDialog: {}
#     });
#
#     $scope.room = mockRoom;
#     $scope.changeDeck();
#   }));
#
#   it('should update $scope.room and $cookieStore', function() {
#     expect(mockRoom.$save).toHaveBeenCalled();
#     expect($cookieStore.put).toHaveBeenCalled();
#   });
# });
# ```
#
# 2. Test if $scope.chooseCard function updates $scope.user.vote:
# ```
# describe('RoomController', function() {
#   beforeEach(module('ATS.Room'));
#
#   var $controller, $rootScope, $scope, FirebaseService;
#   var mockUser = {
#     voter: true,
#     $save: function() {}
#   };
#
#   beforeEach(inject(function(_$controller_, _$rootScope_, _FirebaseService_) {
#     $controller = _$controller_;
#     $rootScope = _$rootScope_;
#     $scope = $rootScope.$new();
#     FirebaseService = _FirebaseService_;
#
#     spyOn(mockUser, '$save');
#
#     $controller('RoomController', {
#       $rootScope: $rootScope,
#       $scope: $scope,
#       $routeParams: {},
#       $location: {},
#       $cookieStore: {},
#       FirebaseService: FirebaseService,
#       ResultsService: {},
#       DeckFactory: {},
#       $mdDialog: {}
#     });
#
#     $scope.user = mockUser;
#     $scope.chooseCard(5, "5", "");
#   }));
#
#   it('should update $scope.user.vote', function() {
#     expect(mockUser.$save).toHaveBeenCalled();
#     expect($scope.user.vote.val).toEqual(5);
#     expect($scope.user.vote.text).toEqual("5");
#     expect($scope.user.vote.fa).toEqual("");
#   });
# });
# ```
#
# 3. Test if $scope.deckIsEmpty function returns true when selectedDeck is empty:
# ```
# describe('RoomController', function() {
#   beforeEach(module('ATS.Room'));
#
#   var $controller, $rootScope, $scope, FirebaseService, DeckFactory;
#   var mockDeck = {
#     cards: []
#   };
#
#   beforeEach(inject(function(_$controller_, _$rootScope_, _FirebaseService_, _DeckFactory_) {
#     $controller = _$controller_;
#     $rootScope = _$rootScope_;
#     $scope = $rootScope.$new();
#     FirebaseService = _FirebaseService_;
#     DeckFactory = _DeckFactory_;
#
#     spyOn(DeckFactory, 'getDecks').and.returnValue([mockDeck]);
#
#     $controller('RoomController', {
#       $rootScope: $rootScope,
#       $scope: $scope,
#       $routeParams: {},
#       $location: {},
#       $cookieStore: {},
#       FirebaseService: FirebaseService,
#       ResultsService: {},
#       DeckFactory: DeckFactory,
#       $mdDialog: {}
#     });
#
#     $scope.selectedDeck = mockDeck;
#   }));
#
#   it('should return true when selectedDeck is empty', function() {
#     expect($scope.deckIsEmpty()).toBeTruthy();
#   });
# });
# ```
#
# 4. Test if $scope.reset function resets $scope.room and $scope.room.reveal:
# ```
# describe('RoomController', function() {
#   beforeEach(module('ATS.Room'));
#
#   var $controller, $rootScope, $scope, FirebaseService;
#   var mockRoom = {
#     users: {
#       user1: {
#         vote: {
#           val: 5,
#           text: "5",
#           fa: ""
#         }
#       },
#       user2: {
#         vote: {
#           val: 2,
#           text: "2",
#           fa: ""
#         }
#       }
#     },
#     reveal: true,
#     $save: function() {}
#   };
#
#   beforeEach(inject(function(_$controller_, _$rootScope_, _FirebaseService_) {
#     $controller = _$controller_;
#     $rootScope = _$rootScope_;
#     $scope = $rootScope.$new();
#     FirebaseService = _FirebaseService_;
#
#     spyOn(mockRoom, '$save');
#
#     $controller('RoomController', {
#       $rootScope: $rootScope,
#       $scope: $scope,
#       $routeParams: {},
#       $location: {},
#       $cookieStore: {},
#       FirebaseService: FirebaseService,
#       ResultsService: {},
#       DeckFactory: {},
#       $mdDialog: {}
#     });
#
#     $scope.room = mockRoom;
#     $scope.reset();
#   }));
#
#   it('should reset $scope.room and $scope.room.reveal', function() {
#     expect(mockRoom.$save).toHaveBeenCalled();
#     expect($scope.room.reveal).toBeFalsy();
#     expect(mockRoom.users.user1.vote).toBeNull();
#     expect(mockRoom.users.user2.vote).toBeNull();
#   });
# });
# ```
#
# 5. Test if $scope.reveal function updates $scope.room.results and $scope.room.reveal:
# ```
# describe('RoomController', function() {
#   beforeEach(module('ATS.Room'));
#
#   var $controller, $rootScope, $scope, FirebaseService, ResultsService;
#   var mockRoom = {
#     users: {
#       user1: {
#         vote: {
#           val: 5,
#           text: "5",
#           fa: ""
#         }
#       },
#       user2: {
#         vote: {
#           val: 2,
#           text: "2",
#           fa: ""
#         }
#       }
#     },
#     reveal: false,
#     $save: function() {}
#   };
#   var mockDeck = {
#     cards: [{
#       text: "1",
#       val: 1,
#       fa: ""
#     }, {
#       text: "2",
#       val: 2,
#       fa: ""
#     }, {
#       text: "3",
#       val: 3,
#       fa: ""
#     }, {
#       text: "5",
#       val: 5,
#       fa: ""
#     }]
#   };
#
#   beforeEach(inject(function(_$controller_, _$rootScope_, _FirebaseService_, _ResultsService_) {
#     $controller = _$controller_;
#     $rootScope = _$rootScope_;
#     $scope = $rootScope.$new();
#     FirebaseService = _FirebaseService_;
#     ResultsService = _ResultsService_;
#
#     spyOn(ResultsService, 'getResults').and.returnValue([{
#       val: 5,
#       text: "5",
#       fa: ""
#     }, {
#       val: 2,
#       text: "2",
#       fa: ""
#     }]);
#
#     spyOn(mockRoom, '$save');
#
#     $controller('RoomController', {
#       $rootScope: $rootScope,
#       $scope: $scope,
#       $routeParams: {},
#       $location: {},
#       $cookieStore: {},
#       FirebaseService: FirebaseService,
#       ResultsService: ResultsService,
#       DeckFactory: {},
#       $mdDialog: {}
#     });
#
#     $scope.room = mockRoom;
#     $scope.selectedDeck = mockDeck;
#     $scope.reveal();
#   }));
#
#   it('should update $scope.room.results and $scope.room.reveal', function() {
#     expect(mockRoom.$save).toHaveBeenCalled();
#     expect($scope.room.reveal).toBeTruthy();
#     expect(ResultsService.getResults).toHaveBeenCalledWith(mockRoom.users, mockDeck);
#     expect($scope.room.results).toEqual([{
#       val: 5,
#       text: "5",
#       fa: ""
#     }, {
#       val: 2,
#       text: "2",
#       fa: ""
#     }]);
#   });
# });
# ```<class 'generator'>
